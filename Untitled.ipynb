# %%
import pandas as pd

# %%
df = pd.read_csv('../neurobubbles/data_preproc/participant.csv')

# %%
a = df.groupby('quiz_grade').session.count()
a.name = 'Count'
a.to_frame()
# Out:
#             Count
# quiz_grade
# 0               7
# 1               9
# 2              18
# 3              26
# 4              13
# 5               6
